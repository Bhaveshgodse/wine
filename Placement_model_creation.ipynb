# %%
import numpy as np
import pandas as pd
df=pd.read_csv("winequality-red.csv")

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
X=df.drop(columns=["quality"])
Y=df["quality"]

# %%
a=df.groupby("quality")
a.first()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3                 11.6              0.58         0.66             2.2
# 4                  7.4              0.59         0.08             4.4
# 5                  7.4              0.70         0.00             1.9
# 6                 11.2              0.28         0.56             1.9
# 7                  7.3              0.65         0.00             1.2
# 8                  7.9              0.35         0.46             3.6
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# quality
# 3            0.074                 10.0                  47.0   1.0008  3.25
# 4            0.086                  6.0                  29.0   0.9974  3.38
# 5            0.076                 11.0                  34.0   0.9978  3.51
# 6            0.075                 17.0                  60.0   0.9980  3.16
# ...

# %% [markdown]
# # Without Scaling

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=.25,random_state=2)

from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score


# scaler=StandardScaler()
# x_train_scaled=scaler.fit_transform(x_train)
# x_test_scaled= scaler.transform(x_test)
LG=LogisticRegression().fit(x_train,y_train)
y_pred=LG.predict(x_test)
accuracy_score(y_test,y_pred)


result=LG.predict(np.array([[6,96,32,45,34,23,56,76,67,43,12]]))
result[0]
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 5

# %%
y_test
# Out:
# 407     7
# 1220    6
# 1200    6
# 308     6
# 1328    5
#        ..
# 7       7
# 732     5
# 1241    5
# 586     7
# 544     6
# Name: quality, Length: 400, dtype: int64

# %%
y_pred
# Out:
# array([6, 6, 6, 5, 5, 6, 5, 5, 5, 5, 6, 6, 5, 6, 5, 6, 6, 6, 6, 6, 5, 6,
#        6, 6, 5, 6, 5, 6, 6, 5, 5, 6, 5, 6, 6, 5, 6, 6, 6, 6, 5, 5, 6, 5,
#        5, 6, 6, 6, 6, 5, 5, 5, 5, 6, 5, 5, 6, 5, 6, 6, 5, 5, 6, 5, 6, 6,
#        6, 6, 6, 6, 5, 5, 6, 5, 5, 6, 6, 6, 6, 5, 5, 6, 6, 6, 6, 6, 5, 5,
#        5, 6, 6, 5, 5, 5, 5, 6, 5, 5, 5, 5, 6, 5, 5, 5, 5, 6, 5, 5, 6, 6,
#        6, 5, 5, 6, 6, 6, 5, 6, 6, 6, 4, 6, 6, 5, 6, 5, 7, 6, 6, 5, 6, 5,
#        6, 5, 6, 5, 6, 6, 5, 6, 6, 6, 6, 6, 6, 6, 6, 5, 5, 6, 5, 6, 6, 5,
#        6, 6, 6, 5, 5, 6, 5, 5, 5, 5, 6, 7, 6, 6, 5, 5, 6, 6, 6, 6, 6, 6,
#        5, 6, 5, 6, 5, 6, 5, 6, 6, 5, 5, 5, 6, 6, 5, 6, 5, 5, 5, 6, 5, 5,
#        5, 6, 5, 6, 5, 5, 5, 5, 6, 6, 6, 5, 7, 5, 5, 5, 6, 6, 6, 6, 6, 6,
#        5, 6, 5, 6, 5, 5, 5, 6, 5, 5, 6, 5, 5, 5, 6, 5, 6, 6, 6, 5, 6, 5,
#        5, 6, 6, 6, 5, 6, 5, 6, 5, 5, 5, 5, 6, 6, 5, 5, 6, 6, 6, 5, 5, 5,
#        6, 6, 5, 5, 5, 6, 5, 6, 5, 6, 5, 5, 5, 5, 6, 5, 6, 6, 5, 6, 6, 5,
# ...

# %%
x_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 579            10.6             0.310         0.49             2.2      0.063
# 455            11.3             0.620         0.67             5.2      0.086
# 803             7.7             0.560         0.08             2.5      0.114
# 341            10.6             0.420         0.48             2.7      0.065
# 102             8.1             0.545         0.18             1.9      0.080
# ...             ...               ...          ...             ...        ...
# 299             6.9             0.670         0.06             2.1      0.080
# 1558            6.9             0.630         0.33             6.7      0.235
# 493             8.7             0.690         0.31             3.0      0.086
# 527             7.0             0.380         0.49             2.5      0.097
# 1192            7.2             0.250         0.37             2.5      0.063
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=.25,random_state=2)

from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score


scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled= scaler.transform(x_test)
LG=LogisticRegression().fit(x_train_scaled,y_train)
y_pred=LG.predict(x_test_scaled)
accuracy_score(y_test,y_pred)

result=LG.predict(scaler.transform([[6,96,32,45,34,23,56,76,67,43,12]]))

result[0]
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 3

# %% [markdown]
# # pickeling and unpickeling

# %%
import pickle
pickle.dump(LG,open("model.pkl","wb"))

# %%
df.sample(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 664            12.1              0.40         0.52             2.0      0.092
# 745             7.3              0.51         0.18             2.1      0.070
# 1472            7.6              0.35         0.60             2.6      0.073
# 1317            9.9              0.44         0.46             2.2      0.091
# 453            10.4              0.33         0.63             2.8      0.084
# 1493            7.7              0.54         0.26             1.9      0.089
# 1183            6.8              0.66         0.07             1.6      0.070
# 26              7.6              0.41         0.24             1.8      0.080
# 935             8.8              0.30         0.38             2.3      0.060
# 1588            7.2              0.66         0.33             2.5      0.068
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
LG.predict(np.array([[0, 0,0]]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 LG.predict(np.array([[0, 0,0]]))
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:425, in LinearClassifierMixin.predict(self, X)
#     411 def predict(self, X):
#     412     """
#     413     Predict class labels for samples in X.
#     414
#    (...)
#     423         Vector containing the class labels for each sample.
#     424     """
# --> 425     scores = self.decision_function(X)
#     426     if len(scores.shape) == 1:
#     427         indices = (scores > 0).astype(int)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:407, in LinearClassifierMixin.decision_function(self, X)
#     387 """
#     388 Predict confidence scores for samples.
#     389
#    (...)
#     403     this class would be predicted.
#     404 """
# ...
